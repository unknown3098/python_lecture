# %%
balance = 0

def deposit(amount):
  global balance
  balance += amount
  return balance

def withdraw(amount):
  global balance
  balance -= amount
  return balance

print(despoit(100))
print(withdraw(30))

# %%
balance1 = 0
balance2 = 0

def deposit1(amount):
  global balance1
  balance1 += amount
  return balance1

def withdraw(amount):
  global balance1
  balance1 += amount
  return balance1

def deposit2(amount):
  global balance2
  balance2 += amount
  return balance2

def withdraw2(amount):
  global balance2
  balance2 += amount
  return balance2

print(deposit1(100))
print(withdraw(30)

print(deposit2(100))
print(withdraw2(30)



print(deposit2(30))

# %%
class Account:
    def __init__(self):
        self.balance = 0

    def deposit(self, amount):
        self.balance += amount
        return self.balance

    def withdraw(self, amount):
        self.balance -= amount
        return self.balance

a1 = Account()
print(a1.deposit(100))
print(a1.withdraw(30))

a2 = Account()
print(a2.deposit(70))
print(a2.withdraw(20))

# %%
class Account:
    balance = 0

    def deposit(self, amount):
        self.balance += amount
        return self.balance

    def withdraw(self, amount):
        self.balance -= amount
        return self.balance

# %%
a2 = Account()
print(a2,desposit(70))
print(a2.withdraw(20))

# %%
class Account:
  def __init__(self):
    self.balance = 0

  def deposit(self,amount):
    self.balance += amount
    return self.balance

  def withdraw(self, amount):
    self.balance -= amount
    return self.balance

# %%
a1 = Account()

# %%
class Account:
  def __init__(self, amount):
    self.balance = amount

  def desposit(self, amount):
    self.balance += amount
    return self.balance

  def withdraw(self, amount):
    self.balance -= amount
    return self.balance

# %%
a1 = Account(50)

# %%
a2 = Account()

# %%
class Account:
  def __init__(self, amount=0):
    self.balance = amount

  def deposit(self, amount):

    self.balance += amount
    return self.balance

  def withdraw(self, amount):
    self.balance -= amount
    return self.balance

a1 = Account(50)
print(a1.deposit(70))

a2 = Account()
print(a2.deposit(100))
# Out:
#   File "/tmp/ipykernel_7866/2444479932.py", line 18
#     print(a2.deposit(100)
#                          ^
# SyntaxError: incomplete input

# %%
class Account:
  def __init__(self, amount=0):
               self.balance = amount

  def desposit(self, amount):
    self.balance += amount
    return self.balance

  def withdraw(self, amount):
    self.balance -= amount
    return self.balance

a1=Account(50)
a1.balance = 30
print(a1.balance)

# %%
class Accoumt:
  def __init__(self, amount=0):
    self.balance = amount

  def deposit(self, amount):
    self.balance += amount
    return self.balance

  def withdraw(self, amount):
    self.balance -= amount
    return self.balance

a1 = Account(50)
print(a1.balance)

# %%
class Account:
  def__init__(self, amount=0):
    self.__balance = amount

  def deposit(self, amount):
    self.__balance += amount
    return self.__balance

  def withdraw(self, amount):
    self.__balance -= amount
    return self.__balance

  def get_balance(self):
    return self.__balance

a1 = Account(50)
print(a1.get_balance())

# %%
import math

class Circle:
    def __init__(self, radius):
        return self.__radius

    def calculate_area(self):
        return math.pi * self.radius ** 2

    def calculate_circumference(self):
        return 2 * math.pi * self.radius

c1 = Circle(7)
print('넓이': c1.get_area())
print('둘레': c1.get_circumference())
c1.set_radius(10)
print('넓이': c1.get_area())
print('둘레': c1.get_circumference())

# %%
class Student:
  def __init__(self, name, computer, math):
    self.name = name
    self.computer = computer
    self.math = math

  def get_name(self):
    return self.__name

  def get_avarge(self):
    return (self.computer + self.math)/2

  def set_math(self, math):
    self._math = math

# %%
class Student:
  def __init__(self, name, computer):
    self.name = name
    self.computer = computer

  def set_computer(self, computer):
    self.computer = computer

  def get_name(self):
    return self.name

# %%
from typing import Self
class Science(Student):
  def __init__(self, name, computer, science):
    super().__init__(name, computer)
    self.science = science

  def set_scence(self, science):
    self.science = science

  def get_average(self):
    return (self.computer + self.science)/2

# %%
class Liberalarts(Student):
  def __init__(self, name, computer, social):
    super().__init__(name, computer)
    self.social = social

  def set_social(self, social):
    self.social = social

  def get_average(self):
    return (self.computer + self.social)/2

# %%
str1 = Science("hanbit1", 90, 80)

# %%
print(str1.get_average())

# %%
str.set_computer(100)
print(str1.get_average())

# %%
st2 = Liberalarts("hanbit2", 98, 88)
print(st2.get_average())
st2.set_social(96)
print(st2.get_average())

# %%
class Figure:
  def __init__(self, area, perimeter):
    self.area = area
    self.perimeter = perimeter

  def get_area(self):
    return self.area

  def get_perimeter(self):
    return self.perimeter

  class Circle(Figure):
    def __init__(self, radius=10):
      area = 3.14*radius**2
      perimeter = 3.14*2*radius
      super().__init__(area, perimeter)

      self.radius = radius

    def set_radius(self, radius):
      self.radius = radius
      area = 3.14*radius**2
      perimeter = 3.14*2*radius

    def get_radius(self):
      return self.radius


    class Rectangle(Figure):
    def __init__(self, width=10, height=10):
        area = width * height
        perimeter = 2 * width + 2 * height
        super().__init__(area, perimeter)
        self.width = width
        self.height = height

    def set_width(self, width):
        self.width = width
        self.area = width * self.height
        self.perimeter = 2 * width + 2 * self.height

    def set_height(self, height):
        self.height = height
        self.area = self.width * height
        self.perimeter = 2 * self.width + 2 * height

    def get_width(self):
        return self.width

    def get_height(self):
        return self.height

# 테스트 코드 부분
f1 = Circle(7)
print(f1.get_area(), f1.get_perimeter())
f1.set_radius(10)
print(f1.get_area(), f1.get_perimeter())

f2 = Rectangle(5, 4)
print(f2.get_area(), f2.get_perimeter())
f2.set_width(7)
print(f2.get_area(), f2.get_perimeter())

# %%
class Car:
  def __init__(self, model, fuelefficiency):
    Self.model = model
    self.fuelefficiency = fuelefficiency

# %%
class Car:
  def get_model(self):
    return self.model

  def get_fuelefficiency(self):
    return self.fuelefficiency

# %%
class Car:

  def set_fuelefficiency(self, fuelefficiency):
    self.fuelefficiency = fuelefficiency

# %%
class ChildProcessError

def get_fuelefficiency(self, distance):
  return self.fuelefficiency

# %%
car1 = Car('GV70', 12)

# %%
print('모델명', car.get_model())
print('연비', car.get_fuelefficiency())
print('연료량', car1.get_fuelamount(240))

# %%
from os import name
class Student:
  def __init__(self, name, computer):
    self.name = name
    self.computer = computer

  def set_computer(self, computer):
    self.computer = computer

  def get_name(self):
    return self.name

# %%
class Science(Student):
  def__init__(self, name, computer, science):
    super().__init__(name, computer)
    self.science = science

  def get_science(self, science):
    self.. science = science

  def get_total(self):
    return self.computer + self.science

  def get_avarage(self):
    return (self.science+self.computer)/2

# %%
class Liberalarts(Student):
  def __init__(self, computer, social):
    super(). __init__(name)
